# %% [markdown]
# <a href="https://colab.research.google.com/github/Melikeda/PythonLibraries/blob/main/TipsDataSet_Filtering_Selecting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# **Filtering / Selecting**

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['TIP']
# Out:
# 0      2.998279
# 1      2.998279
# 2      3.500000
# 3      3.310000
# 4      3.610000
#          ...
# 239    5.920000
# 240    2.000000
# 241    2.000000
# 242    2.998279
# 243    3.000000
# Name: TIP, Length: 244, dtype: float64

# %%
df.iloc[0]
# Out:
# total_bill       16.99
# TIP           2.998279
# sex             FEMALE
# smoker              No
# day                sun
# time            Dinner
# size                 2
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#    total_bill       TIP     sex smoker  day    time  size
# 0       16.99  2.998279  FEMALE     No  sun  Dinner     2
# 1       10.34  2.998279    MALE     No  sun  Dinner     3
# 2       21.01  3.500000    MALE     No  sun  Dinner     3
# 3       23.68  3.310000    MALE     No  sun  Dinner     2

# %%
df.loc[0, 'sex']
# Out:
# 'FEMALE'

# %%
df.loc[0:3,['sex','time']]
# Out:
#       sex    time
# 0  FEMALE  Dinner
# 1    MALE  Dinner
# 2    MALE  Dinner
# 3    MALE  Dinner

# %%
df[df['size'] > 3]
# Out:
#      total_bill   TIP     sex smoker   day    time  size
# 4         24.59  3.61  FEMALE     No   sun  Dinner     4
# 5         25.29  4.71    MALE     No   sun  Dinner     4
# 7         26.88  3.12    MALE     No   sun  Dinner     4
# 11        35.26  5.00  FEMALE     No   sun  Dinner     4
# 13        18.43  3.00    MALE     No   sun  Dinner     4
# 23        39.42  7.58    MALE     No   sat  Dinner     4
# 25        17.81  2.34    MALE     No   sat  Dinner     4
# 31        18.35  2.50    MALE     No   sat  Dinner     4
# 33        20.69  2.45  FEMALE     No   sat  Dinner     4
# 44        30.40  5.60    MALE     No   sun  Dinner     4
# 47        32.40  6.00    MALE     No   sun  Dinner     4
# 52        34.81  5.20  FEMALE     No   sun  Dinner     4
# 54        25.56  4.34    MALE     No   sun  Dinner     4
# 56        38.01  3.00    MALE    Yes   sat  Dinner     4
# 59        48.27  6.73    MALE     No   sat  Dinner     4
# ...

# %%
df[(df['size'] > 4) & (df['day'] == 'sat')]
# Out:
#      total_bill  TIP   sex smoker  day    time  size
# 216       28.15  3.0  MALE    Yes  sat  Dinner     5

# %%
df[df['day'].isin(['thur'])]
# Out:
#      total_bill   TIP     sex smoker   day    time  size
# 77        27.20  4.00    MALE     No  thur   Lunch     4
# 78        22.76  3.00    MALE     No  thur   Lunch     2
# 79        17.29  2.71    MALE     No  thur   Lunch     2
# 80        19.44  3.00    MALE    Yes  thur   Lunch     2
# 81        16.66  3.40    MALE     No  thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 202       13.00  2.00  FEMALE    Yes  thur   Lunch     2
# 203       16.40  2.50  FEMALE    Yes  thur   Lunch     2
# 204       20.53  4.00    MALE    Yes  thur   Lunch     4
# 205       16.47  3.23  FEMALE    Yes  thur   Lunch     3
# 243       18.78  3.00  FEMALE     No  thur  Dinner     2
#
# [62 rows x 7 columns]

# %%
df[df['smoker'].str.contains('No')]
# Out:
#      total_bill       TIP     sex smoker   day    time  size
# 0         16.99  2.998279  FEMALE     No   sun  Dinner     2
# 1         10.34  2.998279    MALE     No   sun  Dinner     3
# 2         21.01  3.500000    MALE     No   sun  Dinner     3
# 3         23.68  3.310000    MALE     No   sun  Dinner     2
# 4         24.59  3.610000  FEMALE     No   sun  Dinner     4
# ..          ...       ...     ...    ...   ...     ...   ...
# 235       10.07  2.998279    MALE     No   sat  Dinner     2
# 238       35.83  4.670000  FEMALE     No   sat  Dinner     3
# 239       29.03  5.920000    MALE     No   sat  Dinner     3
# 242       17.82  2.998279    MALE     No   sat  Dinner     2
# 243       18.78  3.000000  FEMALE     No  thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
df[df['TIP'] > 1].sort_values(by='TIP', ascending=True)
# Out:
#      total_bill    TIP   sex smoker   day    time  size
# 6          8.77   2.00  MALE     No   sun  Dinner     2
# 26        13.37   2.00  MALE     No   sat  Dinner     2
# 27        12.69   2.00  MALE     No   sat  Dinner     2
# 36        16.31   2.00  MALE     No   sat  Dinner     3
# 61        13.81   2.00  MALE    Yes   sat  Dinner     2
# ..          ...    ...   ...    ...   ...     ...   ...
# 141       34.30   6.70  MALE     No  thur   Lunch     6
# 59        48.27   6.73  MALE     No   sat  Dinner     4
# 23        39.42   7.58  MALE     No   sat  Dinner     4
# 212       48.33   9.00  MALE     No   sat  Dinner     4
# 170       50.81  10.00  MALE    Yes   sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
df.loc[df['size'] < 2, ['TIP', 'sex']]
# Out:
#           TIP     sex
# 67   2.998279  FEMALE
# 82   2.998279  FEMALE
# 111  2.998279  FEMALE
# 222  2.998279    MALE
