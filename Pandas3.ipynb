# %% [markdown]
# <a href="https://colab.research.google.com/github/Melikeda/PythonLibraries/blob/main/Pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_37['Units Sold'].plot(kind='hist', bins=20, title='Units Sold')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_38.groupby('Day').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
coffee["Price"] = 4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Unit Sold  Price
# 0     Monday    Espresso          10        NaN   4.99
# 1     Monday       Latte          10       10.0   4.99
# 2    Tuesday    Espresso          30        NaN   4.99
# 3    Tuesday       Latte          20        NaN   4.99
# 4  Wednesday    Espresso          35        NaN   4.99

# %%
import numpy as np

coffee['New_Price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)

coffee
# Out:
#           Day Coffee Type  Units Sold  Unit Sold  Price  New_Price
# 0      Monday    Espresso          10        NaN   4.99       3.99
# 1      Monday       Latte          10       10.0   4.99       5.99
# 2     Tuesday    Espresso          30        NaN   4.99       3.99
# 3     Tuesday       Latte          20        NaN   4.99       5.99
# 4   Wednesday    Espresso          35        NaN   4.99       3.99
# 5   Wednesday       Latte          25        NaN   4.99       5.99
# 6    Thursday    Espresso          40        NaN   4.99       3.99
# 7    Thursday       Latte          30        NaN   4.99       5.99
# 8      Friday    Espresso          45        NaN   4.99       3.99
# 9      Friday       Latte          35        NaN   4.99       5.99
# 10   Saturday    Espresso          45        NaN   4.99       3.99
# 11   Saturday       Latte          35        NaN   4.99       5.99
# 12     Sunday    Espresso          45        NaN   4.99       3.99
# ...

# %%
coffee.drop(columns = ['Price', 'Unit Sold'])
# Out:
#           Day Coffee Type  Units Sold  New_Price
# 0      Monday    Espresso          10       3.99
# 1      Monday       Latte          10       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99
