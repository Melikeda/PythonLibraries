# %% [markdown]
# <a href="https://colab.research.google.com/github/Melikeda/PythonLibraries/blob/main/Pandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
coffee = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[[0,1], 'Units Sold'] = np.nan
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso         NaN
# 1     Monday       Latte         NaN
# 2    Tuesday    Espresso        30.0
# 3    Tuesday       Latte        20.0
# 4  Wednesday    Espresso        35.0

# %%
coffee.fillna(10000)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso     10000.0
# 1      Monday       Latte     10000.0
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte        20.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        35.0
# 1      Monday       Latte        35.0
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte        20.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.fillna(coffee['Units Sold'].interpolate())
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso         NaN
# 1      Monday       Latte         NaN
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte        20.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso         NaN
# 1  Monday       Latte         NaN

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso        30.0
# 3     Tuesday       Latte        20.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    240.0
# Latte       180.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    40.0
# Latte       30.0
# Name: Units Sold, dtype: float64

# %%
coffee['Price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)
coffee
# Out:
#           Day Coffee Type  Units Sold  New_Price  Price
# 0      Monday    Espresso         NaN       3.99   3.99
# 1      Monday       Latte         NaN       5.99   5.99
# 2     Tuesday    Espresso        30.0       3.99   3.99
# 3     Tuesday       Latte        20.0       5.99   5.99
# 4   Wednesday    Espresso        35.0       3.99   3.99
# 5   Wednesday       Latte        25.0       5.99   5.99
# 6    Thursday    Espresso        40.0       3.99   3.99
# 7    Thursday       Latte        30.0       5.99   5.99
# 8      Friday    Espresso        45.0       3.99   3.99
# 9      Friday       Latte        35.0       5.99   5.99
# 10   Saturday    Espresso        45.0       3.99   3.99
# 11   Saturday       Latte        35.0       5.99   5.99
# 12     Sunday    Espresso        45.0       3.99   3.99
# 13     Sunday       Latte        35.0       5.99   5.99

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold':'sum', 'Price':'mean'})
# Out:
#              Units Sold  Price
# Coffee Type
# Espresso          240.0   3.99
# Latte             180.0   5.99
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Units Sold'].plot(kind='hist', bins=20, title='Units Sold')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Price'].plot(kind='hist', bins=20, title='Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Coffee Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...
